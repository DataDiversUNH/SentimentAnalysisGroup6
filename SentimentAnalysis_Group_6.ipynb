# %%
import pandas as pd
import numpy as np

import re
import sys

from textblob import TextBlob as tb

import matplotlib.pyplot as plt
import seaborn as sns

import warnings as w
w.filterwarnings("ignore", category=DeprecationWarning)

from gensim.models import KeyedVectors
from sklearn.manifold import TSNE

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
df = pd.read_csv("C:/Users/mandh/OneDrive/Desktop/Final_Project/Twitter_Sentiment/uk_pm.csv")
print(df)
# Out:
#                          id  \
# 0       1584696134693711873
# 1       1584696057841098752
# 2       1584695906091536385
# 3       1584695822658441217
# 4       1584695640696946688
# ...                     ...
# 113573  1584553348736421888
# 113574  1584553348677525505
# 113575  1584553348597895168
# 113576  1584553348132397056
# 113577  1584553347998105600
#
#                                                      text         username  \
# 0       @BritIndianVoice @RishiSunak #RishiSunak is #B...      IsmailYSyed
# 1       #RishiSunak is the richest Tory MP in history....       AdameMedia
# 2                                             #RishiSunak  ROHITKU96224077
# 3       A mountain full of money and a knowledge of pr...       Parisistas
# 4       @trussliz @RishiSunak Chance was been given as...    baboo_prasant
# ...                                                   ...              ...
# 113573  @JackBarbour_ @piersmorgan @RishiSunak The man...       aqeelone22
# 113574  @Jacob_Rees_Mogg @RishiSunak Let's hope you're...    EddieThornley
# 113575  @sajidjavid @RishiSunak Desperate call for a d...      pedleysjohn
# 113576  @SkyNews Rulling Party needs a strong oppositi...         KarobiVC
# 113577  @trussliz @RishiSunak Liz Truss has won the ma...       sands_hill
#
#                                                  hashtags  \
# 0       ['RishiSunak', 'BritishHindu', 'Pakistani', 'P...
# 1                                          ['RishiSunak']
# 2                                          ['RishiSunak']
# 3                                          ['RishiSunak']
# 4                                          ['RishiSunak']
# ...                                                   ...
# 113573                                                NaN
# 113574                                                NaN
# 113575                            ['ToriesUnfitToGovern']
# 113576                                                NaN
# 113577                                                NaN
#
#                        created_at  user followers count  replycount  \
# 0       2022-10-24 23:59:35+00:00                   393           0
# 1       2022-10-24 23:59:17+00:00                  9830           3
# 2       2022-10-24 23:58:40+00:00                     3           0
# 3       2022-10-24 23:58:21+00:00                     0           0
# 4       2022-10-24 23:57:37+00:00                    14           0
# ...                           ...                   ...         ...
# 113573  2022-10-24 14:32:12+00:00                  1162           0
# 113574  2022-10-24 14:32:12+00:00                    97           0
# 113575  2022-10-24 14:32:12+00:00                  2484           0
# 113576  2022-10-24 14:32:12+00:00                   392           0
# 113577  2022-10-24 14:32:12+00:00                     4           0
#
#         retweetcount  likecount  quotecount language  quotedtweet  \
# 0                  0          0           0       en          NaN
# 1                 23         68           4       en          NaN
# 2                  0          0           0      qht          NaN
# 3                  0          0           0       en          NaN
# 4                  0          0           0       en          NaN
# ...              ...        ...         ...      ...          ...
# 113573             0          0           0       en          NaN
# 113574             0          0           0       en          NaN
# 113575             0          0           0       en          NaN
# 113576             0          0           0       en          NaN
# 113577             0          0           0       en          NaN
#
#         inReplyToTweetId                        inReplyToUser  \
# 0           1.584541e+18  https://twitter.com/BritIndianVoice
# 1                    NaN                                  NaN
# 2                    NaN                                  NaN
# 3                    NaN                                  NaN
# 4           1.584546e+18         https://twitter.com/trussliz
# ...                  ...                                  ...
# 113573      1.584532e+18     https://twitter.com/JackBarbour_
# 113574      1.584539e+18  https://twitter.com/Jacob_Rees_Mogg
# 113575      1.584401e+18       https://twitter.com/sajidjavid
# 113576      1.584512e+18          https://twitter.com/SkyNews
# 113577      1.584546e+18         https://twitter.com/trussliz
#
#                                            mentionedUsers
# 0       @BritIndianVoice @RishiSunak #RishiSunak is #B...
# 1       #RishiSunak is the richest Tory MP in history....
# 2                                             #RishiSunak
# 3       A mountain full of money and a knowledge of pr...
# 4       @trussliz @RishiSunak Chance was been given as...
# ...                                                   ...
# 113573  @JackBarbour_ @piersmorgan @RishiSunak The man...
# 113574  @Jacob_Rees_Mogg @RishiSunak Let's hope you're...
# 113575  @sajidjavid @RishiSunak Desperate call for a d...
# 113576  @SkyNews Rulling Party needs a strong oppositi...
# 113577  @trussliz @RishiSunak Liz Truss has won the ma...
#
# [113578 rows x 15 columns]

# %%
df.columns
# Out:
# Index(['id', 'text', 'username', 'hashtags', 'created_at',
#        'user followers count', 'replycount', 'retweetcount', 'likecount',
#        'quotecount', 'language', 'quotedtweet', 'inReplyToTweetId',
#        'inReplyToUser', 'mentionedUsers'],
#       dtype='object')

# %%
#cHECKING FOR NULL VALUES

df.isnull().any()
# Out:
# id                      False
# text                    False
# username                False
# hashtags                 True
# created_at              False
# user followers count    False
# replycount              False
# retweetcount            False
# likecount               False
# quotecount              False
# language                False
# quotedtweet              True
# inReplyToTweetId         True
# inReplyToUser            True
# mentionedUsers          False
# dtype: bool

# %%
df.isnull().sum()
# Out:
# id                           0
# text                         0
# username                     0
# hashtags                 86621
# created_at                   0
# user followers count         0
# replycount                   0
# retweetcount                 0
# likecount                    0
# quotecount                   0
# language                     0
# quotedtweet             113578
# inReplyToTweetId         30210
# inReplyToUser            30210
# mentionedUsers               0
# dtype: int64

# %%
df.dtypes
# Out:
# id                        int64
# text                     object
# username                 object
# hashtags                 object
# created_at               object
# user followers count      int64
# replycount                int64
# retweetcount              int64
# likecount                 int64
# quotecount                int64
# language                 object
# quotedtweet             float64
# inReplyToTweetId        float64
# inReplyToUser            object
# mentionedUsers           object
# dtype: object

# %% [markdown]
# # DATA CLEANING

# %%
#DELETING UNWANTED COLUMNS

del df['quotedtweet']
del df['inReplyToTweetId']
del df['inReplyToUser']

# %%
df.head(10)
# Out:
#                     id                                               text  \
# 0  1584696134693711873  @BritIndianVoice @RishiSunak #RishiSunak is #B...
# 1  1584696057841098752  #RishiSunak is the richest Tory MP in history....
# 2  1584695906091536385                                        #RishiSunak
# 3  1584695822658441217  A mountain full of money and a knowledge of pr...
# 4  1584695640696946688  @trussliz @RishiSunak Chance was been given as...
# 5  1584695280238465025  @RishiSunak has added a new meaning to the who...
# 6  1584694868646821888  Why are we remembering #WinstonChurchill when ...
# 7  1584694808794497026  I see a lot of white ass is getting burnt... \...
# 8  1584694622538076164  Now when hearing the name of UK feels like Uni...
# 9  1584694437695090689  Time Wheel - Now It's an Indian to Look after ...
#
#           username                                           hashtags  \
# 0      IsmailYSyed  ['RishiSunak', 'BritishHindu', 'Pakistani', 'P...
# 1       AdameMedia                                     ['RishiSunak']
# 2  ROHITKU96224077                                     ['RishiSunak']
# 3       Parisistas                                     ['RishiSunak']
# 4    baboo_prasant                                     ['RishiSunak']
# 5           boovco                                     ['RishiSunak']
# 6     R2d2c3poreal                 ['WinstonChurchill', 'RishiSunak']
# 7    mjtheseafarer                                     ['RishiSunak']
# 8         aitchdei  ['UK', 'RishiSunak', 'UnitedKingdom', 'GB', 'k...
# 9        steemflow  ['RishiSunakPM', 'RishiSunak', 'election', 'In...
#
#                   created_at  user followers count  replycount  retweetcount  \
# 0  2022-10-24 23:59:35+00:00                   393           0             0
# 1  2022-10-24 23:59:17+00:00                  9830           3            23
# 2  2022-10-24 23:58:40+00:00                     3           0             0
# 3  2022-10-24 23:58:21+00:00                     0           0             0
# 4  2022-10-24 23:57:37+00:00                    14           0             0
# 5  2022-10-24 23:56:11+00:00                   584           0             0
# 6  2022-10-24 23:54:33+00:00                   406           0             0
# 7  2022-10-24 23:54:19+00:00                    46           0             0
# 8  2022-10-24 23:53:34+00:00                  1180           1             0
# 9  2022-10-24 23:52:50+00:00                   505           0             0
#
#    likecount  quotecount language  \
# 0          0           0       en
# 1         68           4       en
# 2          0           0      qht
# 3          0           0       en
# 4          0           0       en
# 5          0           0       en
# 6          0           0       en
# 7          0           0       en
# 8          0           0       en
# 9          2           0       en
#
#                                       mentionedUsers
# 0  @BritIndianVoice @RishiSunak #RishiSunak is #B...
# 1  #RishiSunak is the richest Tory MP in history....
# 2                                        #RishiSunak
# 3  A mountain full of money and a knowledge of pr...
# 4  @trussliz @RishiSunak Chance was been given as...
# 5  @RishiSunak has added a new meaning to the who...
# 6  Why are we remembering #WinstonChurchill when ...
# 7  I see a lot of white ass is getting burnt... \...
# 8  Now when hearing the name of UK feels like Uni...
# 9  Time Wheel - Now It's an Indian to Look after ...

# %%
#IMPUTING NaN VALUES IN hashtags COLUMN

df['hashtags'].fillna('ignore',inplace=True)

# %%
df.isnull().sum()
# Out:
# id                      0
# text                    0
# username                0
# hashtags                0
# created_at              0
# user followers count    0
# replycount              0
# retweetcount            0
# likecount               0
# quotecount              0
# language                0
# mentionedUsers          0
# dtype: int64

# %%
#CONVERTING ALL TWEETS TO LOWERCASE

df['tweets'] = df['text'].apply(lambda x: " ".join(x.lower() for x in x.split()))
df['tweets'].head()
# Out:
# 0    @britindianvoice @rishisunak #rishisunak is #b...
# 1    #rishisunak is the richest tory mp in history....
# 2                                          #rishisunak
# 3    a mountain full of money and a knowledge of pr...
# 4    @trussliz @rishisunak chance was been given as...
# Name: tweets, dtype: object

# %%
#REMOVING PUNCTUATION MARKS IN TWEETS

df['tweets'] = df['tweets'].str.replace('[@\#\,\.]','')
df['tweets'].head()
# Out:
# C:\Users\mandh\AppData\Local\Temp\ipykernel_580\1645583283.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['tweets'] = df['tweets'].str.replace('[@\#\,\.]','')
# 0    britindianvoice rishisunak rishisunak is briti...
# 1    rishisunak is the richest tory mp in history h...
# 2                                           rishisunak
# 3    a mountain full of money and a knowledge of pr...
# 4    trussliz rishisunak chance was been given as p...
# Name: tweets, dtype: object

# %%
#REMOVING EMOJIS FROM TWEETS

def remove_emoticons(text):
    emoticon_pattern = re.compile("["
                           u"\U0001F600-\U0001F64F"  # emoticons
                           u"\U0001F300-\U0001F5FF"  # symbols & pictographs
                           u"\U0001F680-\U0001F6FF"  # transport & map symbols
                           u"\U0001F1E0-\U0001F1FF"  # flags 
                           u"\U00002702-\U000027B0"
                           u"\U000024C2-\U0001F251"
                           "]+", flags=re.UNICODE)
    return emoticon_pattern.sub(r'', text)
df['tweets'] = df['tweets'].apply(lambda x: remove_emoticons(x))

# %%
#REMOVING STOP WORDS (a,an, the) FROM THE TWEETS

from nltk.corpus import stopwords
stop = stopwords.words('english')
df['tweets'] = df['tweets'].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
df.head(10)
# Out:
#                     id                                               text  \
# 0  1584696134693711873  @BritIndianVoice @RishiSunak #RishiSunak is #B...
# 1  1584696057841098752  #RishiSunak is the richest Tory MP in history....
# 2  1584695906091536385                                        #RishiSunak
# 3  1584695822658441217  A mountain full of money and a knowledge of pr...
# 4  1584695640696946688  @trussliz @RishiSunak Chance was been given as...
# 5  1584695280238465025  @RishiSunak has added a new meaning to the who...
# 6  1584694868646821888  Why are we remembering #WinstonChurchill when ...
# 7  1584694808794497026  I see a lot of white ass is getting burnt... \...
# 8  1584694622538076164  Now when hearing the name of UK feels like Uni...
# 9  1584694437695090689  Time Wheel - Now It's an Indian to Look after ...
#
#           username                                           hashtags  \
# 0      IsmailYSyed  ['RishiSunak', 'BritishHindu', 'Pakistani', 'P...
# 1       AdameMedia                                     ['RishiSunak']
# 2  ROHITKU96224077                                     ['RishiSunak']
# 3       Parisistas                                     ['RishiSunak']
# 4    baboo_prasant                                     ['RishiSunak']
# 5           boovco                                     ['RishiSunak']
# 6     R2d2c3poreal                 ['WinstonChurchill', 'RishiSunak']
# 7    mjtheseafarer                                     ['RishiSunak']
# 8         aitchdei  ['UK', 'RishiSunak', 'UnitedKingdom', 'GB', 'k...
# 9        steemflow  ['RishiSunakPM', 'RishiSunak', 'election', 'In...
#
#                   created_at  user followers count  replycount  retweetcount  \
# 0  2022-10-24 23:59:35+00:00                   393           0             0
# 1  2022-10-24 23:59:17+00:00                  9830           3            23
# 2  2022-10-24 23:58:40+00:00                     3           0             0
# 3  2022-10-24 23:58:21+00:00                     0           0             0
# 4  2022-10-24 23:57:37+00:00                    14           0             0
# 5  2022-10-24 23:56:11+00:00                   584           0             0
# 6  2022-10-24 23:54:33+00:00                   406           0             0
# 7  2022-10-24 23:54:19+00:00                    46           0             0
# 8  2022-10-24 23:53:34+00:00                  1180           1             0
# 9  2022-10-24 23:52:50+00:00                   505           0             0
#
#    likecount  quotecount language  \
# 0          0           0       en
# 1         68           4       en
# 2          0           0      qht
# 3          0           0       en
# 4          0           0       en
# 5          0           0       en
# 6          0           0       en
# 7          0           0       en
# 8          0           0       en
# 9          2           0       en
#
#                                       mentionedUsers  \
# 0  @BritIndianVoice @RishiSunak #RishiSunak is #B...
# 1  #RishiSunak is the richest Tory MP in history....
# 2                                        #RishiSunak
# 3  A mountain full of money and a knowledge of pr...
# 4  @trussliz @RishiSunak Chance was been given as...
# 5  @RishiSunak has added a new meaning to the who...
# 6  Why are we remembering #WinstonChurchill when ...
# 7  I see a lot of white ass is getting burnt... \...
# 8  Now when hearing the name of UK feels like Uni...
# 9  Time Wheel - Now It's an Indian to Look after ...
#
#                                               tweets
# 0  britindianvoice rishisunak rishisunak britishh...
# 1  rishisunak richest tory mp history wife billio...
# 2                                         rishisunak
# 3  mountain full money knowledge proven theories ...
# 4  trussliz rishisunak chance given pm didn’t ful...
# 5  rishisunak added new meaning whole mba pm pipe...
# 6  remembering winstonchurchill rishisunak going ...
# 7         see lot white ass getting burnt rishisunak
# 8  hearing name uk feels like united kailasa uk r...
# 9  time wheel - indian look british rishisunakpm ...

# %%
import nltk
nltk.download('wordnet')
nltk.download('omw-1.4')

#PERFORMING LEMMETIZATION FOR GRAMMETICAL ERRORS


from nltk.stem import WordNetLemmatizer
lemmatizer = WordNetLemmatizer()
def lemit(comment):
    return lemmatizer.lemmatize(comment)

df['tweets'] = df['tweets'].apply(lemit)
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     C:\Users\mandh\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to
# [nltk_data]     C:\Users\mandh\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!

# %%
df
# Out:
#                          id  \
# 0       1584696134693711873
# 1       1584696057841098752
# 2       1584695906091536385
# 3       1584695822658441217
# 4       1584695640696946688
# ...                     ...
# 113573  1584553348736421888
# 113574  1584553348677525505
# 113575  1584553348597895168
# 113576  1584553348132397056
# 113577  1584553347998105600
#
#                                                      text         username  \
# 0       @BritIndianVoice @RishiSunak #RishiSunak is #B...      IsmailYSyed
# 1       #RishiSunak is the richest Tory MP in history....       AdameMedia
# 2                                             #RishiSunak  ROHITKU96224077
# 3       A mountain full of money and a knowledge of pr...       Parisistas
# 4       @trussliz @RishiSunak Chance was been given as...    baboo_prasant
# ...                                                   ...              ...
# 113573  @JackBarbour_ @piersmorgan @RishiSunak The man...       aqeelone22
# 113574  @Jacob_Rees_Mogg @RishiSunak Let's hope you're...    EddieThornley
# 113575  @sajidjavid @RishiSunak Desperate call for a d...      pedleysjohn
# 113576  @SkyNews Rulling Party needs a strong oppositi...         KarobiVC
# 113577  @trussliz @RishiSunak Liz Truss has won the ma...       sands_hill
#
#                                                  hashtags  \
# 0       ['RishiSunak', 'BritishHindu', 'Pakistani', 'P...
# 1                                          ['RishiSunak']
# 2                                          ['RishiSunak']
# 3                                          ['RishiSunak']
# 4                                          ['RishiSunak']
# ...                                                   ...
# 113573                                             ignore
# 113574                                             ignore
# 113575                            ['ToriesUnfitToGovern']
# 113576                                             ignore
# 113577                                             ignore
#
#                        created_at  user followers count  replycount  \
# 0       2022-10-24 23:59:35+00:00                   393           0
# 1       2022-10-24 23:59:17+00:00                  9830           3
# 2       2022-10-24 23:58:40+00:00                     3           0
# 3       2022-10-24 23:58:21+00:00                     0           0
# 4       2022-10-24 23:57:37+00:00                    14           0
# ...                           ...                   ...         ...
# 113573  2022-10-24 14:32:12+00:00                  1162           0
# 113574  2022-10-24 14:32:12+00:00                    97           0
# 113575  2022-10-24 14:32:12+00:00                  2484           0
# 113576  2022-10-24 14:32:12+00:00                   392           0
# 113577  2022-10-24 14:32:12+00:00                     4           0
#
#         retweetcount  likecount  quotecount language  \
# 0                  0          0           0       en
# 1                 23         68           4       en
# 2                  0          0           0      qht
# 3                  0          0           0       en
# 4                  0          0           0       en
# ...              ...        ...         ...      ...
# 113573             0          0           0       en
# 113574             0          0           0       en
# 113575             0          0           0       en
# 113576             0          0           0       en
# 113577             0          0           0       en
#
#                                            mentionedUsers  \
# 0       @BritIndianVoice @RishiSunak #RishiSunak is #B...
# 1       #RishiSunak is the richest Tory MP in history....
# 2                                             #RishiSunak
# 3       A mountain full of money and a knowledge of pr...
# 4       @trussliz @RishiSunak Chance was been given as...
# ...                                                   ...
# 113573  @JackBarbour_ @piersmorgan @RishiSunak The man...
# 113574  @Jacob_Rees_Mogg @RishiSunak Let's hope you're...
# 113575  @sajidjavid @RishiSunak Desperate call for a d...
# 113576  @SkyNews Rulling Party needs a strong oppositi...
# 113577  @trussliz @RishiSunak Liz Truss has won the ma...
#
#                                                    tweets
# 0       britindianvoice rishisunak rishisunak britishh...
# 1       rishisunak richest tory mp history wife billio...
# 2                                              rishisunak
# 3       mountain full money knowledge proven theories ...
# 4       trussliz rishisunak chance given pm didn’t ful...
# ...                                                   ...
# 113573  jackbarbour_ piersmorgan rishisunak man white ...
# 113574  jacob_rees_mogg rishisunak let's hope governme...
# 113575  sajidjavid rishisunak desperate call decent jo...
# 113576  skynews rulling party needs strong opposition ...
# 113577  trussliz rishisunak liz truss mandate conserva...
#
# [113578 rows x 13 columns]

# %% [markdown]
# # DIVIDING DATASET FOR TRAINING AND TESTING MODEL

# %%
# dIVING THE DATASET FOR TRAINING AND TESTING

train_set = df.iloc[:80000,:]
test_set = df.iloc[80000:,:]

# %%
test_set
# Out:
#                          id  \
# 80000   1584582275777589248
# 80001   1584582275609788418
# 80002   1584582275156430848
# 80003   1584582275148439552
# 80004   1584582275018018817
# ...                     ...
# 113573  1584553348736421888
# 113574  1584553348677525505
# 113575  1584553348597895168
# 113576  1584553348132397056
# 113577  1584553347998105600
#
#                                                      text         username  \
# 80000   The cost of living crisis, the climate crisis ...       GrahamWroe
# 80001   @shiv73257007 @TheFocu62560470 @swapAltAcc @Ac...  Manoran11459457
# 80002   @RichardNeilso15 @Jacob_Rees_Mogg @RishiSunak ...       Burleylass
# 80003   @chhcalling @RishiSunak May we see the list of...     noelle_nole1
# 80004   @LiamFox @RishiSunak As many senior Conservati...         rod21198
# ...                                                   ...              ...
# 113573  @JackBarbour_ @piersmorgan @RishiSunak The man...       aqeelone22
# 113574  @Jacob_Rees_Mogg @RishiSunak Let's hope you're...    EddieThornley
# 113575  @sajidjavid @RishiSunak Desperate call for a d...      pedleysjohn
# 113576  @SkyNews Rulling Party needs a strong oppositi...         KarobiVC
# 113577  @trussliz @RishiSunak Liz Truss has won the ma...       sands_hill
#
#                        hashtags                 created_at  \
# 80000       ['ChaosCostsLives']  2022-10-24 16:27:09+00:00
# 80001                    ignore  2022-10-24 16:27:09+00:00
# 80002                    ignore  2022-10-24 16:27:09+00:00
# 80003                    ignore  2022-10-24 16:27:09+00:00
# 80004                    ignore  2022-10-24 16:27:09+00:00
# ...                         ...                        ...
# 113573                   ignore  2022-10-24 14:32:12+00:00
# 113574                   ignore  2022-10-24 14:32:12+00:00
# 113575  ['ToriesUnfitToGovern']  2022-10-24 14:32:12+00:00
# 113576                   ignore  2022-10-24 14:32:12+00:00
# 113577                   ignore  2022-10-24 14:32:12+00:00
#
#         user followers count  replycount  retweetcount  likecount  quotecount  \
# 80000                    689           0             0          0           0
# 80001                    101           1             0          1           0
# 80002                     67           0             0          1           0
# 80003                   1467           0             0          0           0
# 80004                    230           0             0          1           0
# ...                      ...         ...           ...        ...         ...
# 113573                  1162           0             0          0           0
# 113574                    97           0             0          0           0
# 113575                  2484           0             0          0           0
# 113576                   392           0             0          0           0
# 113577                     4           0             0          0           0
#
#        language                                     mentionedUsers  \
# 80000        en  The cost of living crisis, the climate crisis ...
# 80001        hi  @shiv73257007 @TheFocu62560470 @swapAltAcc @Ac...
# 80002        en  @RichardNeilso15 @Jacob_Rees_Mogg @RishiSunak ...
# 80003        en  @chhcalling @RishiSunak May we see the list of...
# 80004        en  @LiamFox @RishiSunak As many senior Conservati...
# ...         ...                                                ...
# 113573       en  @JackBarbour_ @piersmorgan @RishiSunak The man...
# 113574       en  @Jacob_Rees_Mogg @RishiSunak Let's hope you're...
# 113575       en  @sajidjavid @RishiSunak Desperate call for a d...
# 113576       en  @SkyNews Rulling Party needs a strong oppositi...
# 113577       en  @trussliz @RishiSunak Liz Truss has won the ma...
#
#                                                    tweets
# 80000   cost living crisis climate crisis nature crisi...
# 80001   shiv73257007 thefocu62560470 swapaltacc activi...
# 80002   richardneilso15 jacob_rees_mogg rishisunak dec...
# 80003   chhcalling rishisunak may see list 102 bojo ba...
# 80004   liamfox rishisunak many senior conservative fi...
# ...                                                   ...
# 113573  jackbarbour_ piersmorgan rishisunak man white ...
# 113574  jacob_rees_mogg rishisunak let's hope governme...
# 113575  sajidjavid rishisunak desperate call decent jo...
# 113576  skynews rulling party needs strong opposition ...
# 113577  trussliz rishisunak liz truss mandate conserva...
#
# [33578 rows x 13 columns]

# %%
#PERFORMING SENTIMENT ANALYSIS TO GIVE THE POLARITY TO TWEETS USING TextBlob

def sentiment_analysis(train_set):
    def get_subjectivity(text): #FINDING OUT THE SUBJECTIVITY OF TEXT IN DATASET
        return tb(text).sentiment.subjectivity
    def get_polarity(text):  #FINDING THE POLARITY OF TEXT IN DATASET
        return tb(text).sentiment.polarity
    train_set['Subjectivity'] = train_set['tweets'].apply(get_subjectivity) #ADDING COLUMNS SUBJECTIVITY AND POLARITY IN DATASET
    train_set['Polarity'] = train_set['tweets'].apply(get_polarity)
    def get_Analysis(score):
        if score < 0:
            return -1
        elif score == 0:
            return 0
        else:
            return 1
    train_set['label'] = train_set['Polarity'].apply(get_Analysis ) #ADDING COLUMN CALLED LABEL WHICH INDICATES 0,1,-1 FOR NEUTRAL, POSITIVITY AND NEGATIVITY
    return train_set
sentiment_analysis(train_set)
# Out:
# C:\Users\mandh\AppData\Local\Temp\ipykernel_580\1297008409.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_set['Subjectivity'] = train_set['tweets'].apply(get_subjectivity) #ADDING COLUMNS SUBJECTIVITY AND POLARITY IN DATASET
# C:\Users\mandh\AppData\Local\Temp\ipykernel_580\1297008409.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_set['Polarity'] = train_set['tweets'].apply(get_polarity)
# C:\Users\mandh\AppData\Local\Temp\ipykernel_580\1297008409.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_set['label'] = train_set['Polarity'].apply(get_Analysis ) #ADDING COLUMN CALLED LABEL WHICH INDICATES 0,1,-1 FOR NEUTRAL, POSITIVITY AND NEGATIVITY
#                         id                                               text  \
# 0      1584696134693711873  @BritIndianVoice @RishiSunak #RishiSunak is #B...
# 1      1584696057841098752  #RishiSunak is the richest Tory MP in history....
# 2      1584695906091536385                                        #RishiSunak
# 3      1584695822658441217  A mountain full of money and a knowledge of pr...
# 4      1584695640696946688  @trussliz @RishiSunak Chance was been given as...
# ...                    ...                                                ...
# 79995  1584582278285381633  @RishiSunak Bruh,\n\nYou fucked our economy.\n...
# 79996  1584582278239244312  Congratulations Mr Rishi sunak for becoming UK...
# 79997  1584582277778280450  @Jacob_Rees_Mogg @RishiSunak Borisorbust! Gues...
# 79998  1584582277178064896  @julie_hymes @son_of_kernow @rec777777 @trussl...
# 79999  1584582275853078529  @Conservatives @RishiSunak Elected? Interestin...
#
#               username                                           hashtags  \
# 0          IsmailYSyed  ['RishiSunak', 'BritishHindu', 'Pakistani', 'P...
# 1           AdameMedia                                     ['RishiSunak']
# 2      ROHITKU96224077                                     ['RishiSunak']
# 3           Parisistas                                     ['RishiSunak']
# 4        baboo_prasant                                     ['RishiSunak']
# ...                ...                                                ...
# 79995          Flxssyy                                             ignore
# 79996          SGK0126                                             ignore
# 79997     onedavidfell                                             ignore
# 79998  billybobmcmanus                                             ignore
# 79999         19welchy                                             ignore
#
#                       created_at  user followers count  replycount  \
# 0      2022-10-24 23:59:35+00:00                   393           0
# 1      2022-10-24 23:59:17+00:00                  9830           3
# 2      2022-10-24 23:58:40+00:00                     3           0
# 3      2022-10-24 23:58:21+00:00                     0           0
# 4      2022-10-24 23:57:37+00:00                    14           0
# ...                          ...                   ...         ...
# 79995  2022-10-24 16:27:09+00:00                   112           0
# 79996  2022-10-24 16:27:09+00:00                     3           0
# 79997  2022-10-24 16:27:09+00:00                    14           0
# 79998  2022-10-24 16:27:09+00:00                  1193           1
# 79999  2022-10-24 16:27:09+00:00                   180           0
#
#        retweetcount  likecount  quotecount language  \
# 0                 0          0           0       en
# 1                23         68           4       en
# 2                 0          0           0      qht
# 3                 0          0           0       en
# 4                 0          0           0       en
# ...             ...        ...         ...      ...
# 79995             0          0           0       en
# 79996             0          0           0       en
# 79997             0          0           0       en
# 79998             0          1           0       en
# 79999             0          0           0       en
#
#                                           mentionedUsers  \
# 0      @BritIndianVoice @RishiSunak #RishiSunak is #B...
# 1      #RishiSunak is the richest Tory MP in history....
# 2                                            #RishiSunak
# 3      A mountain full of money and a knowledge of pr...
# 4      @trussliz @RishiSunak Chance was been given as...
# ...                                                  ...
# 79995  @RishiSunak Bruh,\n\nYou fucked our economy.\n...
# 79996  Congratulations Mr Rishi sunak for becoming UK...
# 79997  @Jacob_Rees_Mogg @RishiSunak Borisorbust! Gues...
# 79998  @julie_hymes @son_of_kernow @rec777777 @trussl...
# 79999  @Conservatives @RishiSunak Elected? Interestin...
#
#                                                   tweets  Subjectivity  \
# 0      britindianvoice rishisunak rishisunak britishh...      0.200000
# 1      rishisunak richest tory mp history wife billio...      0.200000
# 2                                             rishisunak      0.000000
# 3      mountain full money knowledge proven theories ...      0.463889
# 4      trussliz rishisunak chance given pm didn’t ful...      0.450000
# ...                                                  ...           ...
# 79995  rishisunak bruh fucked economy we've 4 chancel...      0.375000
# 79996  congratulations mr rishi sunak becoming uk's p...      0.816667
# 79997  jacob_rees_mogg rishisunak borisorbust! guess ...      0.250000
# 79998  julie_hymes son_of_kernow rec777777 trussliz r...      0.000000
# 79999  conservatives rishisunak elected? interesting ...      0.360000
#
#        Polarity  label
# 0      0.200000      1
# 1      0.200000      1
# 2      0.000000      0
# 3      0.352778      1
# 4      0.350000      1
# ...         ...    ...
# 79995 -0.397266     -1
# 79996  0.650000      1
# 79997  0.250000      1
# 79998  0.000000      0
# 79999  0.340000      1
#
# [80000 rows x 16 columns]

# %%
train_set['lengthoftweet'] = train_set['text'].str.len()
test_set['lengthoftweet'] = test_set['text'].str.len()

train_set.head(10)
# Out:
# C:\Users\mandh\AppData\Local\Temp\ipykernel_580\3924243947.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_set['lengthoftweet'] = train_set['text'].str.len()
# C:\Users\mandh\AppData\Local\Temp\ipykernel_580\3924243947.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_set['lengthoftweet'] = test_set['text'].str.len()
#                     id                                               text  \
# 0  1584696134693711873  @BritIndianVoice @RishiSunak #RishiSunak is #B...
# 1  1584696057841098752  #RishiSunak is the richest Tory MP in history....
# 2  1584695906091536385                                        #RishiSunak
# 3  1584695822658441217  A mountain full of money and a knowledge of pr...
# 4  1584695640696946688  @trussliz @RishiSunak Chance was been given as...
# 5  1584695280238465025  @RishiSunak has added a new meaning to the who...
# 6  1584694868646821888  Why are we remembering #WinstonChurchill when ...
# 7  1584694808794497026  I see a lot of white ass is getting burnt... \...
# 8  1584694622538076164  Now when hearing the name of UK feels like Uni...
# 9  1584694437695090689  Time Wheel - Now It's an Indian to Look after ...
#
#           username                                           hashtags  \
# 0      IsmailYSyed  ['RishiSunak', 'BritishHindu', 'Pakistani', 'P...
# 1       AdameMedia                                     ['RishiSunak']
# 2  ROHITKU96224077                                     ['RishiSunak']
# 3       Parisistas                                     ['RishiSunak']
# 4    baboo_prasant                                     ['RishiSunak']
# 5           boovco                                     ['RishiSunak']
# 6     R2d2c3poreal                 ['WinstonChurchill', 'RishiSunak']
# 7    mjtheseafarer                                     ['RishiSunak']
# 8         aitchdei  ['UK', 'RishiSunak', 'UnitedKingdom', 'GB', 'k...
# 9        steemflow  ['RishiSunakPM', 'RishiSunak', 'election', 'In...
#
#                   created_at  user followers count  replycount  retweetcount  \
# 0  2022-10-24 23:59:35+00:00                   393           0             0
# 1  2022-10-24 23:59:17+00:00                  9830           3            23
# 2  2022-10-24 23:58:40+00:00                     3           0             0
# 3  2022-10-24 23:58:21+00:00                     0           0             0
# 4  2022-10-24 23:57:37+00:00                    14           0             0
# 5  2022-10-24 23:56:11+00:00                   584           0             0
# 6  2022-10-24 23:54:33+00:00                   406           0             0
# 7  2022-10-24 23:54:19+00:00                    46           0             0
# 8  2022-10-24 23:53:34+00:00                  1180           1             0
# 9  2022-10-24 23:52:50+00:00                   505           0             0
#
#    likecount  quotecount language  \
# 0          0           0       en
# 1         68           4       en
# 2          0           0      qht
# 3          0           0       en
# 4          0           0       en
# 5          0           0       en
# 6          0           0       en
# 7          0           0       en
# 8          0           0       en
# 9          2           0       en
#
#                                       mentionedUsers  \
# 0  @BritIndianVoice @RishiSunak #RishiSunak is #B...
# 1  #RishiSunak is the richest Tory MP in history....
# 2                                        #RishiSunak
# 3  A mountain full of money and a knowledge of pr...
# 4  @trussliz @RishiSunak Chance was been given as...
# 5  @RishiSunak has added a new meaning to the who...
# 6  Why are we remembering #WinstonChurchill when ...
# 7  I see a lot of white ass is getting burnt... \...
# 8  Now when hearing the name of UK feels like Uni...
# 9  Time Wheel - Now It's an Indian to Look after ...
#
#                                               tweets  Subjectivity  Polarity  \
# 0  britindianvoice rishisunak rishisunak britishh...      0.200000  0.200000
# 1  rishisunak richest tory mp history wife billio...      0.200000  0.200000
# 2                                         rishisunak      0.000000  0.000000
# 3  mountain full money knowledge proven theories ...      0.463889  0.352778
# 4  trussliz rishisunak chance given pm didn’t ful...      0.450000  0.350000
# 5  rishisunak added new meaning whole mba pm pipe...      0.427273  0.168182
# 6  remembering winstonchurchill rishisunak going ...      0.550000  0.200000
# 7         see lot white ass getting burnt rishisunak      0.000000  0.000000
# 8  hearing name uk feels like united kailasa uk r...      0.000000  0.000000
# 9  time wheel - indian look british rishisunakpm ...      0.000000  0.000000
#
#    label  lengthoftweet
# 0      1            309
# 1      1            171
# 2      0             11
# 3      1            279
# 4      1            178
# 5      1             86
# 6      1            166
# 7      0             57
# 8      0            120
# 9      0            129

# %% [markdown]
# ## VISUALIZING POLARITY(LABEL)

# %%
#DESCRIBING THE MEAN, COUNT, STD OF TRAINING DATASET

train_set.groupby('label').describe()
# Out:
#             id                                                          \
#          count          mean           std           min           25%
# label
# -1     12642.0  1.584056e+18  2.801541e+15  1.565207e+18  1.584588e+18
#  0     39188.0  1.584231e+18  2.326794e+15  1.565202e+18  1.584588e+18
#  1     28170.0  1.584074e+18  2.761269e+15  1.565130e+18  1.584583e+18
#
#                                                 user followers count  \
#                 50%           75%           max                count
# label
# -1     1.584610e+18  1.584640e+18  1.584696e+18              12642.0
#  0     1.584608e+18  1.584637e+18  1.584696e+18              39188.0
#  1     1.584605e+18  1.584635e+18  1.584696e+18              28170.0
#
#                     ...  Polarity               lengthoftweet              \
#               mean  ...       75%           max         count        mean
# label               ...
# -1     2910.251701  ... -0.100000 -5.551115e-18       12642.0  165.126879
#  0     5357.041671  ...  0.000000  0.000000e+00       39188.0   97.409819
#  1     5714.070501  ...  0.466667  1.000000e+00       28170.0  162.150266
#
#
#              std   min   25%    50%    75%    max
# label
# -1     82.381836  16.0  95.0  152.0  235.0  896.0
#  0     64.220153  11.0  51.0   78.0  124.0  456.0
#  1     81.089528  14.0  93.0  149.0  231.0  655.0
#
# [3 rows x 72 columns]

# %%
#VISUALIZING THE POLARITY INDEX OF DATASET

train_set['label'].value_counts().plot.pie(y = 'mass', figsize = (7, 4))
# Out:
# <AxesSubplot:ylabel='label'>

# %%
train_set.groupby('lengthoftweet').mean()['label'].plot.hist(color = 'blue', figsize = (6, 4),)
plt.title('variation of length')
plt.xlabel('Length')
plt.show()

# %%
from sklearn.feature_extraction.text import CountVectorizer
#FINDING AND PLOTTING THE TOP 30 MOST FREQUENTLY USED WORDS

cv = CountVectorizer(stop_words = 'english')
words = cv.fit_transform(train_set.text)

sum_words = words.sum(axis=0)

words_freq = [(word, sum_words[0, i]) for word, i in cv.vocabulary_.items()]
words_freq = sorted(words_freq, key = lambda x: x[1], reverse = True)

frequency = pd.DataFrame(words_freq, columns=['word', 'freq'])

frequency.head(30).plot(x='word', y='freq', kind='bar', figsize=(15, 7), color = 'blue')
plt.title("Most Frequently Occuring Words - Top 30")
# Out:
# Text(0.5, 1.0, 'Most Frequently Occuring Words - Top 30')

# %%
from wordcloud import WordCloud

wordcloud = WordCloud(background_color = 'pink', width = 1000, height = 1000).generate_from_frequencies(dict(words_freq))

plt.figure(figsize=(10,8))
plt.imshow(wordcloud)
plt.title("WordCloud - Vocabulary from Tweets", fontsize = 22)
# Out:
# Text(0.5, 1.0, 'WordCloud - Vocabulary from Tweets')

# %%
neutral_words =' '.join([text for text in train_set['tweets'][train_set['label'] == 0]])

wordcloud = WordCloud(background_color = 'white', width=800, height=500, random_state = 0, max_font_size = 110).generate(neutral_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title('The Neutral Words')
plt.show()

# %%
positive_words =' '.join([text for text in train_set['tweets'][train_set['label'] == 1]])

wordcloud = WordCloud(background_color = 'green', width=800, height=500, random_state = 0, max_font_size = 110).generate(positive_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title('The Positive Words')
plt.show()

# %%
negative_words =' '.join([text for text in train_set['tweets'][train_set['label'] == -1]])

wordcloud = WordCloud(background_color = 'red', width=800, height=500, random_state = 0, max_font_size = 110).generate(negative_words)
plt.figure(figsize=(10, 7))
plt.imshow(wordcloud, interpolation="bilinear")
plt.axis('off')
plt.title('The Negative Words')
plt.show()

# %%
# TOKENIZING THE WORDS IN TWEETS IN TRAINING DATASET
tokenized_tweet = train_set['tweets'].apply(lambda x: x.split()) 

# importing gensim
import gensim

# creating a word to vector model
model_w2v = gensim.models.Word2Vec(
            tokenized_tweet,
            #size=200, # desired no. of features/independent variables 
            window=5, # context window size
            min_count=2,
            sg = 1, # 1 for skip-gram model
            hs = 0,
            negative = 10, # for negative sampling
            workers= 2, # no.of cores
            seed = 34)

model_w2v.train(tokenized_tweet, total_examples= len(train_set['tweets']), epochs=20)
# Out:
# (17386116, 20875500)

# %%
model_w2v.wv.most_similar(positive = "people")
# Out:
# [('folk!', 0.7045617699623108),
#  ('ppl', 0.6944155693054199),
#  ('victims?', 0.6838895082473755),
#  ('people?', 0.6744601130485535),
#  ('cheerful', 0.668742299079895),
#  ('person??', 0.6595749855041504),
#  ('kenjmunn', 0.6584054231643677),
#  ('peoples', 0.6566780209541321),
#  ('manage!', 0.6543563008308411),
#  ('citizens', 0.6538246870040894)]

# %%
model_w2v.wv.most_similar(positive = "hope")
# Out:
# [('let’s', 0.6487761735916138),
#  ('removes', 0.6352037191390991),
#  ('hoping', 0.6318206787109375),
#  ('hopefully', 0.620128870010376),
#  ('dumps', 0.6066392064094543),
#  ('steadied', 0.6050843000411987),
#  ('sincerely', 0.6036731004714966),
#  ('expect', 0.6024704575538635),
#  ('start!', 0.5892626643180847),
#  ('last!', 0.58819180727005)]

# %%
model_w2v.wv.most_similar(positive = "party")
# Out:
# [('polls!', 0.7372505068778992),
#  ('conservative', 0.731212317943573),
#  ('party!!!', 0.7242576479911804),
#  ('battle:', 0.7216848731040955),
#  ('conservativepartymembers', 0.7152660489082336),
#  ('labourites', 0.7102830410003662),
#  ('(fixed', 0.7094361782073975),
#  ('values!', 0.7040162086486816),
#  ('conserativesuk', 0.7021048665046692),
#  ('irreparably', 0.6986759901046753)]

# %%
model_w2v.wv.most_similar(negative = "mean")
# Out:
# [('biz', 0.07129305601119995),
#  ('var', 0.05504101142287254),
#  ('britainpm', 0.03494236245751381),
#  ('bin', 0.0174417644739151),
#  ('સુનક', 0.008253241889178753),
#  ('180', 0.0030213049612939358),
#  ('ઋષિ', -0.0001543145190225914),
#  ('med', -0.0017053864430636168),
#  ('city', -0.002765597077086568),
#  ('۔', -0.00597309460863471)]

# %%
model_w2v.wv.most_similar(negative = "leader")
# Out:
# [('tanjabueltmann', 0.02571140043437481),
#  (';)', 0.019719893112778664),
#  ('mama2022', -0.010289186611771584),
#  ('milk', -0.011926010251045227),
#  ('psychological', -0.015835372731089592),
#  ('????', -0.016617724671959877),
#  ('ee', -0.02277359552681446),
#  ('disclaimer', -0.023180443793535233),
#  ('manufacture', -0.024247292429208755),
#  ('gi', -0.0264185331761837)]

# %%
model_w2v.wv.most_similar(negative = "bad")
# Out:
# [('message', 0.04062609747052193),
#  ('via', 0.02568705379962921),
#  ('vsreddy_mp', 0.0224610585719347),
#  ('"', 0.007353040389716625),
#  ('rishisunak’s', 0.004909928422421217),
#  ('shayarimran', 0.002432597801089287),
#  ('۔', -0.00459451787173748),
#  ('anglo', -0.007772611454129219),
#  ('oct', -0.009519524872303009),
#  ('leo', -0.013603528030216694)]

# %%
from tqdm import tqdm
tqdm.pandas(desc="progress-bar")
from gensim.models.doc2vec import TaggedDocument

def adding_label(twt):
    output = []
    for i, s in zip(twt.index, twt):
        output.append(TaggedDocument(s, ["tweet_" + str(i)]))
    return output

# label all the tweets
labeled_tweets = adding_label(tokenized_tweet)

labeled_tweets[:6]
# Out:
# [TaggedDocument(words=['britindianvoice', 'rishisunak', 'rishisunak', 'britishhindu', 'paternal', 'pakistani', 'punjabi', 'origin', 'he’s', 'legally', 'poc', '(pakistan', 'origin', 'card)', 'holder', 'issued', 'nadrapak', '(probably', 'also', 'concurrently', 'holding', 'india’s', 'oci', 'indian', 'nri', 'wife/mother)', 'also', 'may', 'issue', 'wife’s', 'indian', 'citizenship'], tags=['tweet_0']),
#  TaggedDocument(words=['rishisunak', 'richest', 'tory', 'mp', 'history', 'wife', 'billionaire', 'suggestion', 'representative', 'asian', 'sound', 'ludicrous', 'ears'], tags=['tweet_1']),
#  TaggedDocument(words=['rishisunak'], tags=['tweet_2']),
#  TaggedDocument(words=['mountain', 'full', 'money', 'knowledge', 'proven', 'theories', 'bit', 'hard', 'work', 'use', 'make', 'goras', 'hug', 'make', 'man', 'pm', '5', 'years', 'best', 'rishisunak', 'rubikaliyaquat', 'anjanaomkashyap', 'sudhirchaudhary', 'irohitr', 'arpitaarya', 'nehabatham03', 'j_paatni'], tags=['tweet_3']),
#  TaggedDocument(words=['trussliz', 'rishisunak', 'chance', 'given', 'pm', 'didn’t', 'fulfilled', 'duty', 'people…', 'late', 'rishisunak', 'take', 'lets', 'hope', 'best', 'uk', 'people'], tags=['tweet_4']),
#  TaggedDocument(words=['rishisunak', 'added', 'new', 'meaning', 'whole', 'mba', 'pm', 'pipeline', 'thing', 'rishisunak'], tags=['tweet_5'])]

# %%
#PERFORMING SENTIMENT ANALYSIS TO TEST THE MODEL

sentiment_analysis(test_set)
# Out:
# C:\Users\mandh\AppData\Local\Temp\ipykernel_580\1297008409.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_set['Subjectivity'] = train_set['tweets'].apply(get_subjectivity) #ADDING COLUMNS SUBJECTIVITY AND POLARITY IN DATASET
# C:\Users\mandh\AppData\Local\Temp\ipykernel_580\1297008409.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_set['Polarity'] = train_set['tweets'].apply(get_polarity)
# C:\Users\mandh\AppData\Local\Temp\ipykernel_580\1297008409.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   train_set['label'] = train_set['Polarity'].apply(get_Analysis ) #ADDING COLUMN CALLED LABEL WHICH INDICATES 0,1,-1 FOR NEUTRAL, POSITIVITY AND NEGATIVITY
#                          id  \
# 80000   1584582275777589248
# 80001   1584582275609788418
# 80002   1584582275156430848
# 80003   1584582275148439552
# 80004   1584582275018018817
# ...                     ...
# 113573  1584553348736421888
# 113574  1584553348677525505
# 113575  1584553348597895168
# 113576  1584553348132397056
# 113577  1584553347998105600
#
#                                                      text         username  \
# 80000   The cost of living crisis, the climate crisis ...       GrahamWroe
# 80001   @shiv73257007 @TheFocu62560470 @swapAltAcc @Ac...  Manoran11459457
# 80002   @RichardNeilso15 @Jacob_Rees_Mogg @RishiSunak ...       Burleylass
# 80003   @chhcalling @RishiSunak May we see the list of...     noelle_nole1
# 80004   @LiamFox @RishiSunak As many senior Conservati...         rod21198
# ...                                                   ...              ...
# 113573  @JackBarbour_ @piersmorgan @RishiSunak The man...       aqeelone22
# 113574  @Jacob_Rees_Mogg @RishiSunak Let's hope you're...    EddieThornley
# 113575  @sajidjavid @RishiSunak Desperate call for a d...      pedleysjohn
# 113576  @SkyNews Rulling Party needs a strong oppositi...         KarobiVC
# 113577  @trussliz @RishiSunak Liz Truss has won the ma...       sands_hill
#
#                        hashtags                 created_at  \
# 80000       ['ChaosCostsLives']  2022-10-24 16:27:09+00:00
# 80001                    ignore  2022-10-24 16:27:09+00:00
# 80002                    ignore  2022-10-24 16:27:09+00:00
# 80003                    ignore  2022-10-24 16:27:09+00:00
# 80004                    ignore  2022-10-24 16:27:09+00:00
# ...                         ...                        ...
# 113573                   ignore  2022-10-24 14:32:12+00:00
# 113574                   ignore  2022-10-24 14:32:12+00:00
# 113575  ['ToriesUnfitToGovern']  2022-10-24 14:32:12+00:00
# 113576                   ignore  2022-10-24 14:32:12+00:00
# 113577                   ignore  2022-10-24 14:32:12+00:00
#
#         user followers count  replycount  retweetcount  likecount  quotecount  \
# 80000                    689           0             0          0           0
# 80001                    101           1             0          1           0
# 80002                     67           0             0          1           0
# 80003                   1467           0             0          0           0
# 80004                    230           0             0          1           0
# ...                      ...         ...           ...        ...         ...
# 113573                  1162           0             0          0           0
# 113574                    97           0             0          0           0
# 113575                  2484           0             0          0           0
# 113576                   392           0             0          0           0
# 113577                     4           0             0          0           0
#
#        language                                     mentionedUsers  \
# 80000        en  The cost of living crisis, the climate crisis ...
# 80001        hi  @shiv73257007 @TheFocu62560470 @swapAltAcc @Ac...
# 80002        en  @RichardNeilso15 @Jacob_Rees_Mogg @RishiSunak ...
# 80003        en  @chhcalling @RishiSunak May we see the list of...
# 80004        en  @LiamFox @RishiSunak As many senior Conservati...
# ...         ...                                                ...
# 113573       en  @JackBarbour_ @piersmorgan @RishiSunak The man...
# 113574       en  @Jacob_Rees_Mogg @RishiSunak Let's hope you're...
# 113575       en  @sajidjavid @RishiSunak Desperate call for a d...
# 113576       en  @SkyNews Rulling Party needs a strong oppositi...
# 113577       en  @trussliz @RishiSunak Liz Truss has won the ma...
#
#                                                    tweets  lengthoftweet  \
# 80000   cost living crisis climate crisis nature crisi...            259
# 80001   shiv73257007 thefocu62560470 swapaltacc activi...            223
# 80002   richardneilso15 jacob_rees_mogg rishisunak dec...             76
# 80003   chhcalling rishisunak may see list 102 bojo ba...             71
# 80004   liamfox rishisunak many senior conservative fi...            209
# ...                                                   ...            ...
# 113573  jackbarbour_ piersmorgan rishisunak man white ...            192
# 113574  jacob_rees_mogg rishisunak let's hope governme...             95
# 113575  sajidjavid rishisunak desperate call decent jo...             76
# 113576  skynews rulling party needs strong opposition ...            151
# 113577  trussliz rishisunak liz truss mandate conserva...            136
#
#         Subjectivity  Polarity  label
# 80000       0.100000  0.000000      0
# 80001       0.066667  0.000000      0
# 80002       0.666667  0.166667      1
# 80003       0.000000  0.000000      0
# 80004       0.477273  0.318182      1
# ...              ...       ...    ...
# 113573      0.225000  0.100000      1
# 113574      0.000000  0.000000      0
# 113575      0.833333 -0.216667     -1
# 113576      0.666667  0.566667      1
# 113577      0.000000  0.000000      0
#
# [33578 rows x 17 columns]

# %% [markdown]
# # LOGISTIC REGRESSION FOR SENTIMENT ANALYSIS

# %%
#UNIGRAM FEATURE

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report,confusion_matrix

vectorizer = CountVectorizer(binary=False,ngram_range=(1,1))
train_features = vectorizer.fit_transform(train_set['tweets'])
test_features = vectorizer.transform(test_set['tweets'])

clf = LogisticRegression(max_iter=1000)
clf.fit(train_features, train_set['label'])
predictions = clf.predict(test_features)
print(classification_report(test_set['label'], predictions, target_names=['-1','0','1']))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.92      0.86      0.89      5002
#            0       0.96      0.99      0.97     16917
#            1       0.96      0.94      0.95     11659
#
#     accuracy                           0.95     33578
#    macro avg       0.95      0.93      0.94     33578
# weighted avg       0.95      0.95      0.95     33578

# %%
#UNIGRAM+BIGRAM FEATURE

# %%
vectorizer = CountVectorizer(binary=False,ngram_range=(1,2))
clf = LogisticRegression(max_iter=1000)
clf.fit(train_features, train_set['label'])

predictions = clf.predict(test_features)
print(classification_report(test_set['label'], predictions, target_names=['-1', '0','1']))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.92      0.86      0.89      5002
#            0       0.96      0.99      0.97     16917
#            1       0.96      0.94      0.95     11659
#
#     accuracy                           0.95     33578
#    macro avg       0.95      0.93      0.94     33578
# weighted avg       0.95      0.95      0.95     33578

# %%
#UNIGRAM+BIGRAM+TRIGRAM FEATURE

# %%
vectorizer = CountVectorizer(binary=False,ngram_range=(1,3))
clf = LogisticRegression(max_iter=1000)
clf.fit(train_features, train_set['label'])

predictions = clf.predict(test_features)
print(classification_report(test_set['label'], predictions, target_names=['-1', '0','1']))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.92      0.86      0.89      5002
#            0       0.96      0.99      0.97     16917
#            1       0.96      0.94      0.95     11659
#
#     accuracy                           0.95     33578
#    macro avg       0.95      0.93      0.94     33578
# weighted avg       0.95      0.95      0.95     33578

# %% [markdown]
# # NAIVE BAYES FOR SENTIMENT ANALYSIS

# %%
#UNIGRAM FEATURE

# %%
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB()
clf.fit(train_features, train_set['label'])
 
predictions = clf.predict(test_features)
print(classification_report(test_set['label'], predictions, target_names=['-1', '0','1']))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.90      0.26      0.40      5002
#            0       0.92      0.77      0.84     16917
#            1       0.61      0.95      0.74     11659
#
#     accuracy                           0.75     33578
#    macro avg       0.81      0.66      0.66     33578
# weighted avg       0.81      0.75      0.74     33578

# %%
#UNIGRAM+BIGRAM FEATURE

# %%
vectorizer = CountVectorizer(binary=False,ngram_range=(1,2))
train_features = vectorizer.fit_transform(train_set['tweets'])
test_features = vectorizer.transform(test_set['tweets'])
clf = MultinomialNB()
clf.fit(train_features, train_set['label'])
 
predictions = clf.predict(test_features)
print(classification_report(test_set['label'], predictions, target_names=['-1', '0','1']))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.88      0.33      0.48      5002
#            0       0.94      0.76      0.84     16917
#            1       0.62      0.96      0.75     11659
#
#     accuracy                           0.76     33578
#    macro avg       0.81      0.68      0.69     33578
# weighted avg       0.82      0.76      0.76     33578

# %%
#UNIGRAM+BIGRAM+TRIGRAM FEATURE

# %%
vectorizer = CountVectorizer(binary=False,ngram_range=(1,3))
train_features = vectorizer.fit_transform(train_set['tweets'])
test_features = vectorizer.transform(test_set['tweets'])
clf = MultinomialNB()
clf.fit(train_features, train_set['label'])
 
predictions = clf.predict(test_features)
print(classification_report(test_set['label'], predictions, target_names=['-1', '0','1']))
# Out:
#               precision    recall  f1-score   support
#
#           -1       0.90      0.26      0.40      5002
#            0       0.92      0.77      0.84     16917
#            1       0.61      0.95      0.74     11659
#
#     accuracy                           0.75     33578
#    macro avg       0.81      0.66      0.66     33578
# weighted avg       0.81      0.75      0.74     33578

# %% [markdown]
# # THANK YOU
